# %%
import numpy as np
import pandas as pd

# %%
# Define the file path
file_path = r"C:\Users\mail2\OneDrive\Desktop\MY_DRIVE\MLOps\MLOps-Addy\sample_data.csv"

# Read the CSV file
data = pd.read_csv(file_path)

# Print the contents of the file
#print(df)
data.head(7)
# Out:
#    Unnamed: 0   Name  Age         City  Salary
# 0           0  Vijay   25     New York   50000
# 1           1  Benyl   35  Los Angeles   60000
# 2           2    Sam   32      Chicago   70000
# 3           3    Ram   40      Houston   80000
# 4           4   Kian   45      Phoenix   55000

# %%
pd.DataFrame(data)
# Out:
#    Unnamed: 0   Name  Age         City  Salary
# 0           0  Vijay   25     New York   50000
# 1           1  Benyl   35  Los Angeles   60000
# 2           2    Sam   32      Chicago   70000
# 3           3    Ram   40      Houston   80000
# 4           4   Kian   45      Phoenix   55000

# %%
tail=data.tail(2)
print(tail)
# Out:
#    Unnamed: 0  Name  Age     City  Salary
# 3           3   Ram   40  Houston   80000
# 4           4  Kian   45  Phoenix   55000

# %%
data.query('Age > 30')
# Out:
#    Unnamed: 0   Name  Age         City  Salary
# 1           1  Benyl   35  Los Angeles   60000
# 2           2    Sam   32      Chicago   70000
# 3           3    Ram   40      Houston   80000
# 4           4   Kian   45      Phoenix   55000

# %%
data.tail(2)
# Out:
#    Unnamed: 0  Name  Age     City  Salary
# 3           3   Ram   40  Houston   80000
# 4           4  Kian   45  Phoenix   55000

# %%
data.describe()
# Out:
#        Unnamed: 0        Age        Salary
# count    5.000000   5.000000      5.000000
# mean     2.000000  35.400000  63000.000000
# std      1.581139   7.635444  12041.594579
# min      0.000000  25.000000  50000.000000
# 25%      1.000000  32.000000  55000.000000
# 50%      2.000000  35.000000  60000.000000
# 75%      3.000000  40.000000  70000.000000
# max      4.000000  45.000000  80000.000000

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           0
# City          0
# Salary        0
# dtype: int64

# %%
data[data["Age"]=40]
# Out:
#   Cell In[12], line 1
#     data[data["Age"]=40]
#          ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
data[data["City"]=="New York"]
# Out:
#    Unnamed: 0   Name  Age      City  Salary
# 0           0  Vijay   40  New York   50000

# %%
data[data["City"]>="New York"]
# Out:
#    Unnamed: 0   Name  Age      City  Salary
# 0           0  Vijay   40  New York   50000
# 4           4   Kian   40   Phoenix   55000

# %%
data[data["Salary"]>=60000]
# Out:
#    Unnamed: 0   Name  Age         City  Salary
# 1           1  Benyl   40  Los Angeles   60000
# 2           2    Sam   40      Chicago   70000
# 3           3    Ram   40      Houston   80000

# %%
data.groupby('City')['Salary'].mean()
# Out:
# City
# Chicago        70000.0
# Houston        80000.0
# Los Angeles    60000.0
# New York       50000.0
# Phoenix        55000.0
# Name: Salary, dtype: float64

# %%
data['Salary'].mean()
# Out:
# np.float64(63000.0)

# %%
data.to_json(r"C:\Users\mail2\OneDrive\Desktop\MY_DRIVE\MLOps\MLOps-Addy\sample_data_output.json", orient='records', lines=True)

# %%
df=pd.DataFrame(data)
print(df)
print(df.corr())
# Out:
#    Unnamed: 0   Name  Age         City  Salary
# 0           0  Vijay   25     New York   50000
# 1           1  Benyl   35  Los Angeles   60000
# 2           2    Sam   32      Chicago   70000
# 3           3    Ram   40      Houston   80000
# 4           4   Kian   45      Phoenix   55000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 df=pd.DataFrame(data)
#       2 print(df)
# ----> 3 print(df.corr())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
# ...
